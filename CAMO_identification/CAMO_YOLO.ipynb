# %%
# !pip install -U ultralytics

from ultralytics import YOLO

# !pip install clearml

import clearml
# Out:
# ...
#      ---------------------------------------- 0.0/660.4 kB ? eta -:--:--
#      -- ---------------------------------- 41.0/660.4 kB 653.6 kB/s eta 0:00:01
#      ------ ------------------------------- 112.6/660.4 kB 1.3 MB/s eta 0:00:01
#      ------------- ------------------------ 235.5/660.4 kB 1.8 MB/s eta 0:00:01
#      ---------------------------- --------- 491.5/660.4 kB 2.6 MB/s eta 0:00:01
#      -------------------------------------  655.4/660.4 kB 2.9 MB/s eta 0:00:01
#      -------------------------------------- 660.4/660.4 kB 2.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.0.200
#     Uninstalling ultralytics-8.0.200:
#       Successfully uninstalled ultralytics-8.0.200
# ...

# %%
# %env CLEARML_WEB_HOST=https://app.clear.ml
# %env CLEARML_API_HOST=https://api.clear.ml
# %env CLEARML_FILES_HOST=https://files.clear.ml
# %env CLEARML_API_ACCESS_KEY=8LZTLIEZK6L4HMEULLJP
# %env CLEARML_API_SECRET_KEY=baxAri7KiCkpHzZpm8aDM7rkHeaq8lYBGMOTTBfKukI4Yg8PZH
# Out:
# env: CLEARML_WEB_HOST=https://app.clear.ml
# env: CLEARML_API_HOST=https://api.clear.ml
# env: CLEARML_FILES_HOST=https://files.clear.ml
# env: CLEARML_API_ACCESS_KEY=8LZTLIEZK6L4HMEULLJP
# env: CLEARML_API_SECRET_KEY=baxAri7KiCkpHzZpm8aDM7rkHeaq8lYBGMOTTBfKukI4Yg8PZH

# %%
from clearml import Task
task = Task.init(project_name="CAMO", task_name="camo_train_1")

# %%
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)
# Out:
# 2023-12-10 15:01:55,607 - clearml.model - WARNING - Connecting multiple input models with the same name: `yolov8n`. This might result in the wrong model being used when executing remotely

# %%
results = model.train(data="C:/Users/rlpat/OneDrive/Documents/New_College/Advanced Applied Computing/camo.yaml", epochs=50)
# Out:
# New https://pypi.org/project/ultralytics/8.0.226 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.200  Python-3.11.3 torch-2.1.0+cpu CPU (Intel Core(TM) i7-9750H 2.60GHz)
# ...

# %%
metrics = model.val()

metrics.box.maps
# Out:
# Ultralytics YOLOv8.0.200  Python-3.11.3 torch-2.1.0+cpu CPU (Intel Core(TM) i7-9750H 2.60GHz)
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "c:\Users\rlpat\anaconda3\envs\jupyterlab\Lib\site-packages\IPython\core\interactiveshell.py", line 3505, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\rlpat\AppData\Local\Temp\ipykernel_33080\1445792294.py", line 1, in <module>
#     metrics = model.val()
#               ^^^^^^^^^^^
#   File "c:\Users\rlpat\anaconda3\envs\jupyterlab\Lib\site-packages\ultralytics\engine\model.py", line 276, in val
#   File "c:\Users\rlpat\anaconda3\envs\jupyterlab\Lib\site-packages\torch\utils\_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\rlpat\anaconda3\envs\jupyterlab\Lib\site-packages\ultralytics\engine\validator.py", line 122, in __call__
# ...
